# %%
# Import packages
import pandas as pd
import re
import ast
import pyMUZ.gen.io as io

# %%
pt = '/Users/marczepeda/Downloads/clinvar_result.txt'
gene = io.get(pt,typ='tsv')
gene
# Out:
#                                                  Name  \
# 0   GRCh38/hg38 14q11.2-21.1(chr14:20000611-389844...
# 1   GRCh38/hg38 14q11.2-21.2(chr14:20022693-440936...
# 2   GRCh38/hg38 14q11.2-21.3(chr14:20043513-486420...
# 3   GRCh38/hg38 14q11.2-32.33(chr14:20043514-10687...
# 4   130056597|LOC130056598|LOC130056599|LOC1300566...
# ..                                                ...
# 63  GRCh37/hg19 14q13.2-21.2(chr14:35934503-471209...
# 64  GRCh37/hg19 14q11.2-32.33(chr14:20511673-10728...
# 65     GRCh37/hg19 14q21.1(chr14:38008667-38214720)x1
# 66  GRCh37/hg19 14q11.2-32.33(chr14:19794561-10723...
# 67  GRCh37/hg19 14q13.3-21.1(chr14:37145530-380641...
#
#                                               Gene(s) Protein change  \
# 0   LOC130055392|LOC130055393|LOC130055394|LOC1300...            NaN
# 1   ABHD4|ACIN1|ADCY4|AJUBA|AKAP6|ANG|AP1G2|AP1G2-...            NaN
# 2   OR10G2|OR10G3|OR11G2|OR11H4|OR11H6|OR11H7|OR4E...            NaN
# ...

# %%
gene_name = 'FOXA1'
gene = gene[gene['Gene(s)']==gene_name].reset_index(drop=True)
gene = gene.dropna(subset='Protein change').reset_index(drop=True)
gene
# Out:
#                                           Name Gene(s) Protein change  \
# 0   NM_004496.5(FOXA1):c.1411A>G (p.Thr471Ala)   FOXA1          T471A
# 1   NM_004496.5(FOXA1):c.1361C>T (p.Ala454Val)   FOXA1          A454V
# 2   NM_004496.5(FOXA1):c.1191C>A (p.Asn397Lys)   FOXA1          N397K
# 3   NM_004496.5(FOXA1):c.1076C>T (p.Pro359Leu)   FOXA1          P359L
# 4   NM_004496.5(FOXA1):c.1066A>T (p.Thr356Ser)   FOXA1          T356S
# 5    NM_004496.5(FOXA1):c.976C>T (p.Pro326Ser)   FOXA1          P326S
# 6    NM_004496.5(FOXA1):c.964G>A (p.Gly322Ser)   FOXA1          G322S
# 7    NM_004496.5(FOXA1):c.962A>T (p.Glu321Val)   FOXA1          E321V
# 8    NM_004496.5(FOXA1):c.943G>A (p.Gly315Arg)   FOXA1          G315R
# 9    NM_004496.5(FOXA1):c.935G>C (p.Gly312Ala)   FOXA1          G312A
# 10   NM_004496.5(FOXA1):c.925C>T (p.Leu309Phe)   FOXA1          L309F
# 11   NM_004496.5(FOXA1):c.888C>A (p.Asp296Glu)   FOXA1          D296E
# ...

# %%
befores = []
nums = []
afters = []
aa_muts = []
for aa_mut in gene['Protein change']:
    num = int(re.findall(r'-?\d+',aa_mut)[0])
    nums.append(num)
    befores.append(aa_mut.split(str(num))[0])
    afters.append(aa_mut.split(str(num))[1])
gene['AA_position']=nums
gene['AA_before']=befores
gene['AA_after']=afters
gene
# Out:
#                                           Name Gene(s) Protein change  \
# 0   NM_004496.5(FOXA1):c.1411A>G (p.Thr471Ala)   FOXA1          T471A
# 1   NM_004496.5(FOXA1):c.1361C>T (p.Ala454Val)   FOXA1          A454V
# 2   NM_004496.5(FOXA1):c.1191C>A (p.Asn397Lys)   FOXA1          N397K
# 3   NM_004496.5(FOXA1):c.1076C>T (p.Pro359Leu)   FOXA1          P359L
# 4   NM_004496.5(FOXA1):c.1066A>T (p.Thr356Ser)   FOXA1          T356S
# 5    NM_004496.5(FOXA1):c.976C>T (p.Pro326Ser)   FOXA1          P326S
# 6    NM_004496.5(FOXA1):c.964G>A (p.Gly322Ser)   FOXA1          G322S
# 7    NM_004496.5(FOXA1):c.962A>T (p.Glu321Val)   FOXA1          E321V
# 8    NM_004496.5(FOXA1):c.943G>A (p.Gly315Arg)   FOXA1          G315R
# 9    NM_004496.5(FOXA1):c.935G>C (p.Gly312Ala)   FOXA1          G312A
# 10   NM_004496.5(FOXA1):c.925C>T (p.Leu309Phe)   FOXA1          L309F
# 11   NM_004496.5(FOXA1):c.888C>A (p.Asp296Glu)   FOXA1          D296E
# ...
